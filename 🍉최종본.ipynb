# %%
from selenium import webdriver
import subprocess
import chromedriver_autoinstaller
from selenium.webdriver.common.by import By
from selenium.webdriver.chrome.options import Options
import chromedriver_autoinstaller
    
from selenium.webdriver.common.keys import Keys

import time
import datetime as dt
import schedule

import pandas as pd
import numpy as np
from pprint import pprint
import urllib.request
import json
import glob
import sys
import os

import warnings
warnings.filterwarnings(action='ignore')

pd.set_option('display.max_columns', 250)
pd.set_option('display.max_rows', 250)
pd.set_option('display.width', 100)

pd.options.display.float_format = '{:.2f}'.format

class NaverDataLabOpenAPI():
    """
    네이버 데이터랩 오픈 API 컨트롤러 클래스
    """

    def __init__(self, client_id, client_secret):
        """
        인증키 설정 및 검색어 그룹 초기화
        """
        self.client_id = client_id
        self.client_secret = client_secret
        self.keywordGroups = []
        self.url = "https://openapi.naver.com/v1/datalab/search"

    def add_keyword_groups(self, group_dict):
        """
        검색어 그룹 추가
        """

        keyword_gorup = {
            'groupName': group_dict['groupName'],
            'keywords': group_dict['keywords']
        }
        
        self.keywordGroups.append(keyword_gorup)
#         print(f">>> Num of keywordGroups: {len(self.keywordGroups)}")
        
    def get_data(self, startDate, endDate, timeUnit, device, ages, gender):
        """
        요청 결과 반환
        timeUnit - 'date', 'week', 'month'
        device - None, 'pc', 'mo'
        ages = [], ['1' ~ '11']
        gender = None, 'm', 'f'
        """

        # Request body
        body = json.dumps({
            "startDate": startDate,
            "endDate": endDate,
            "timeUnit": timeUnit,
            "keywordGroups": self.keywordGroups,
            "device": device,
            "ages": ages,
            "gender": gender
        }, ensure_ascii=False)
        
        # Results
        request = urllib.request.Request(self.url)
        request.add_header("X-Naver-Client-Id",self.client_id)
        request.add_header("X-Naver-Client-Secret",self.client_secret)
        request.add_header("Content-Type","application/json")
        response = urllib.request.urlopen(request, data=body.encode("utf-8"))
        rescode = response.getcode()
        if(rescode==200):
            # Json Result
            result = json.loads(response.read())
            
            period = []
            ratio = []
            title = []
#             pprint(result)
            if result['results'][0]['data']:
                for val in result['results']:
                    period.append(val['data'][-1]['period'])
                    ratio.append(val['data'][-1]['ratio'])
                    title.append(val['title'])
            
            df = pd.DataFrame({"title" : title, 'period' : period, "ratio" : ratio})
            
        else:
            print("Error Code:" + rescode)
            
        return df

keyword_group_set = {
    'keyword_group_1': {'groupName': "애플", 'keywords': ["애플"]},
}
def run():
    print("시작시작시작")
    try:
        subprocess.Popen(r'C:\Program Files\Google\Chrome\Application\chrome.exe --remote-debugging-port=9222 --user-data-dir="C:\chrometemp1"')  # 디버거 크롬 구동
    except:
        subprocess.Popen(r'C:\Program Files (x86)\Google\Chrome\Application\chrome.exe --remote-debugging-port=9222 --user-data-dir="C:\chrometemp1"')  # 디버거 크롬 구동
    option = Options()
    option.add_experimental_option("debuggerAddress", "127.0.0.1:9222")
    # option.add_argument("--headless")

    chrome_ver = chromedriver_autoinstaller.get_chrome_version().split('.')[0]
    try:
        driver = webdriver.Chrome(f'./{chrome_ver}/chromedriver.exe', options=option)
    except:
        chromedriver_autoinstaller.install('./')
        driver = webdriver.Chrome(f'./{chrome_ver}/chromedriver.exe', options=option)

    ######################
    #플라스틱제로 시작
    #####크롤링
    print('plastic start')
    driver.get('https://blackkiwi.net/service/keyword-analysis?keyword=%ED%94%8C%EB%9D%BC%EC%8A%A4%ED%8B%B1%20%EC%A0%9C%EB%A1%9C&platform=naver')
    time.sleep(10) #혹시 모를 에러 방지를 위한 적절한 wait 넣어주기
    title=driver.find_elements(By.CSS_SELECTOR,'table a')
    title_l=[]
    for i in range(20):
        title_l.append(title[i].text)
#         print(title_l[i])
    driver.implicitly_wait(10)
    driver.get('http://surffing.net/MainSeoSearch.do')
    search=driver.find_element(By.ID,'saerchKeyword')
    search.send_keys('플라스틱 제로')
    search.send_keys(Keys.ENTER)
    title2=driver.find_elements(By.CSS_SELECTOR,'tr>td.center:nth-child(1)')
    title_b=[]
    
    for i in range(len(title2)):
        title_b.append(title2[i].text)
#         print(title_b[i])
    
    title_l.extend(title_b)
    list_a=[]
    for i in range(len(title_l)):
            list_a.append(title_l[i].replace(" ", ""))
    li_set=set(list_a)
    list_a=list(li_set)
    
    today = dt.date.today()
    if(today.weekday()==0):
        monday=dt.date.today()-dt.timedelta(+7)
        print(monday)
    else:
        monday=today - dt.timedelta(days=today.weekday())
    days=today.weekday()
    end=monday.strftime('%Y-%m-%d')
    print(end)
    th=dt.timedelta(days=30)
    start=monday-th
    print(start)
    start=start.strftime('%Y-%m-%d')
        
    #####크롤링end
    cnt=0
    while(True):
        if len(list_a)>0 :
            for idx, (key, val) in enumerate(keyword_group_set.items()):
                val['groupName'] = list_a[idx]
                val['keywords'] = [list_a[idx]]
            del list_a[:1]
            cnt+=1
        else:
            break
    #     pprint(keyword_group_set)

            # API 인증 정보 설정
        client_id = "xTsOEpqU869lYEaqyaU6"
        client_secret = "kkp_ZP2j9T"

        # 요청 파라미터 설정
        startDate = start
        endDate = end
        timeUnit = 'week'
        device = ''
        ages = []
        gender = ''

        # 데이터 프레임 정의
        naver = NaverDataLabOpenAPI(client_id=client_id, client_secret=client_secret)

        naver.add_keyword_groups(keyword_group_set['keyword_group_1'])

        df = naver.get_data(startDate, endDate, timeUnit, device, ages, gender)

        if(cnt>1):
            df1=pd.concat([df1,df])
        else:
            df1=df
#     print(df1)
    #검색주간과 같은 데이터만 추출
    df1=df1[df1['period']==end]
    #ratio높은순으로 정렬
    df2=df1.sort_values('ratio',ascending=False)
    #ratio 삭제
    df2=df2.drop([df2.columns[2]],axis=1)
    #인덱싱해주기
    df2.reset_index(drop=True,inplace=True)
    #10위까지 저장
    data=df2.loc[:9]
    print(data)
    
    #db에 데이터 저장
    import cx_Oracle

    dsn = cx_Oracle.makedsn("project-db-stu.ddns.net", 1524, service_name = "XE") # 오라클 주소
    connection = cx_Oracle.connect(user="gjai_4_2_0822", password="smhrd2", dsn=dsn, encoding="UTF-8") # 오라클 접속
    cur = connection.cursor() # 실행 결과 데이터를 담을 메모리 객체
    #dataframe 변환
    df_list = data.to_records(index=False)
    df_list = data.values.tolist()
    #쿼리
    cur.execute("TRUNCATE TABLE plastic_search")
    cur.executemany("INSERT INTO plastic_search (title, day) VALUES (:1,:2)",
            df_list, batcherrors = True)
    cur.execute("commit")
    print('plastic success commit')
    
    
    ######################
    #플라스틱제로 끝
    ######################
    #비건 시작
    
    
    print('vegan start')
    driver.get('https://blackkiwi.net/service/keyword-analysis?keyword=%EB%B9%84%EA%B1%B4&platform=naver')
    time.sleep(10) #혹시 모를 에러 방지를 위한 적절한 wait 넣어주기
    title=driver.find_elements(By.CSS_SELECTOR,'table a')
    title_l=[]
    for i in range(20):
        title_l.append(title[i].text)
#         print(title_l[i])
    driver.implicitly_wait(10)
    driver.get('http://surffing.net/MainSeoSearch.do')
    search=driver.find_element(By.ID,'saerchKeyword')
    search.send_keys('비건')
    search.send_keys(Keys.ENTER)
    title2=driver.find_elements(By.CSS_SELECTOR,'tr>td.center:nth-child(1)')
    title_b=[]

    for i in range(len(title2)):
        title_b.append(title2[i].text)
#         print(title_b[i])
        
    ##채식
    driver.get('https://blackkiwi.net/service/keyword-analysis?keyword=%EC%B1%84%EC%8B%9D&platform=naver')
    time.sleep(10) #혹시 모를 에러 방지를 위한 적절한 wait 넣어주기
    title3=driver.find_elements(By.CSS_SELECTOR,'table a')
    title_3=[]
    for i in range(20):
        title_3.append(title3[i].text)
#         print(title_3[i])
    driver.implicitly_wait(10)
    driver.get('http://surffing.net/MainSeoSearch.do')
    search=driver.find_element(By.ID,'saerchKeyword')
    search.send_keys('채식')
    search.send_keys(Keys.ENTER)
    title4=driver.find_elements(By.CSS_SELECTOR,'tr>td.center:nth-child(1)')
    title_4=[]

    for i in range(len(title4)):
        title_4.append(title4[i].text)
#         print(title_4[i])
    
    title_l.extend(title_b)
    title_l.extend(title_3)
    title_l.extend(title_4)
    list_a=[]
    for i in range(len(title_l)):
            list_a.append(title_l[i].replace(" ", ""))
    li_set=set(list_a)
    list_a=list(li_set)
    
    cnt=0
    while(True):
        if len(list_a)>0 :
            for idx, (key, val) in enumerate(keyword_group_set.items()):
                val['groupName'] = list_a[idx]
                val['keywords'] = [list_a[idx]]
            del list_a[:1]
            cnt+=1
        else:
            break
    #     pprint(keyword_group_set)

            # API 인증 정보 설정
        client_id = "xTsOEpqU869lYEaqyaU6"
        client_secret = "kkp_ZP2j9T"

        # 요청 파라미터 설정
        startDate = start
        endDate = end
        timeUnit = 'week'
        device = ''
        ages = []
        gender = ''

        # 데이터 프레임 정의
        naver = NaverDataLabOpenAPI(client_id=client_id, client_secret=client_secret)

        naver.add_keyword_groups(keyword_group_set['keyword_group_1'])

        df = naver.get_data(startDate, endDate, timeUnit, device, ages, gender)

        if(cnt>1):
            df1=pd.concat([df1,df])
        else:
            df1=df
#     print(df1)
    #검색주간과 같은 데이터만 추출
    df1=df1[df1['period']==end]
    #ratio높은순으로 정렬
    df2=df1.sort_values('ratio',ascending=False)
    #ratio 삭제
    df2=df2.drop([df2.columns[2]],axis=1)
    #인덱싱해주기
    df2.reset_index(drop=True,inplace=True)
    #10위까지 저장
    data=df2.loc[:9]
    print(data)
    
    #db에 데이터 저장
    import cx_Oracle

    dsn = cx_Oracle.makedsn("project-db-stu.ddns.net", 1524, service_name = "XE") # 오라클 주소
    connection = cx_Oracle.connect(user="gjai_4_2_0822", password="smhrd2", dsn=dsn, encoding="UTF-8") # 오라클 접속
    cur = connection.cursor() # 실행 결과 데이터를 담을 메모리 객체
    #dataframe 변환
    df_list = data.to_records(index=False)
    df_list = data.values.tolist()
    #쿼리
    cur.execute("TRUNCATE TABLE vegan_search")
    cur.executemany("INSERT INTO vegan_search (title, day) VALUES (:1,:2)",
            df_list, batcherrors = True)
    cur.execute("commit")
    print('vegan commit')
    
    ######################
    #비건 끝
    ######################
    #제로웨이스트 시작
    print('zerowaste start')
    driver.get('https://blackkiwi.net/service/keyword-analysis?keyword=%EC%A0%9C%EB%A1%9C%EC%9B%A8%EC%9D%B4%EC%8A%A4%ED%8A%B8&platform=naver')
    time.sleep(10) #혹시 모를 에러 방지를 위한 적절한 wait 넣어주기
    title=driver.find_elements(By.CSS_SELECTOR,'table a')
    title_l=[]
    for i in range(20):
        title_l.append(title[i].text)
#         print(title_l[i])
    driver.implicitly_wait(10)
    driver.get('http://surffing.net/MainSeoSearch.do')
    search=driver.find_element(By.ID,'saerchKeyword')
    search.send_keys('제로웨이스트')
    search.send_keys(Keys.ENTER)
    title2=driver.find_elements(By.CSS_SELECTOR,'tr>td.center:nth-child(1)')
    title_b=[]

    for i in range(len(title2)):
        title_b.append(title2[i].text)
#         print(title_b[i])
    
    title_l.extend(title_b)
    list_a=[]
    for i in range(len(title_l)):
            list_a.append(title_l[i].replace(" ", ""))
    li_set=set(list_a)
    list_a=list(li_set)
    

        
    #####크롤링end
    cnt=0
    while(True):
        if len(list_a)>0 :
            for idx, (key, val) in enumerate(keyword_group_set.items()):
                val['groupName'] = list_a[idx]
                val['keywords'] = [list_a[idx]]
            del list_a[:1]
            cnt+=1
        else:
            break
    #     pprint(keyword_group_set)

            # API 인증 정보 설정
        client_id = "xTsOEpqU869lYEaqyaU6"
        client_secret = "kkp_ZP2j9T"

        # 요청 파라미터 설정
        startDate = start
        endDate = end
        timeUnit = 'week'
        device = ''
        ages = []
        gender = ''

        # 데이터 프레임 정의
        naver = NaverDataLabOpenAPI(client_id=client_id, client_secret=client_secret)

        naver.add_keyword_groups(keyword_group_set['keyword_group_1'])

        df = naver.get_data(startDate, endDate, timeUnit, device, ages, gender)

        if(cnt>1):
            df1=pd.concat([df1,df])
        else:
            df1=df
#     print(df1)

    #드라이버닫기
    driver.close()
    #검색주간과 같은 데이터만 추출
    df1=df1[df1['period']==end]
    #ratio높은순으로 정렬
    df2=df1.sort_values('ratio',ascending=False)
    #ratio 삭제
    df2=df2.drop([df2.columns[2]],axis=1)
    #인덱싱해주기
    #인덱싱해주기
    df2.reset_index(drop=True,inplace=True)
    #10위까지 저장
    data=df2.loc[:9]
    print(data)
    
     #db에 데이터 저장
    import cx_Oracle

    dsn = cx_Oracle.makedsn("project-db-stu.ddns.net", 1524, service_name = "XE") # 오라클 주소
    connection = cx_Oracle.connect(user="gjai_4_2_0822", password="smhrd2", dsn=dsn, encoding="UTF-8") # 오라클 접속
    cur = connection.cursor() # 실행 결과 데이터를 담을 메모리 객체
    #dataframe 변환
    df_list = data.to_records(index=False)
    df_list = data.values.tolist()
    #쿼리
    cur.execute("TRUNCATE TABLE zerowaste_search")
    cur.executemany("INSERT INTO zerowaste_search (title, day) VALUES (:1,:2)",
            df_list, batcherrors = True)
    cur.execute("commit")
    print('zerowaste commit')
    
    
    
    
    
    cur.close()
    connection.close()

    
    
# step3.실행 주기 설정
# schedule.every().tuesday.at("02:00").do(run)
schedule.every().day.at("21:24").do(run)

# step4.스캐쥴 시작
while True:
    schedule.run_pending()
    time.sleep(1)
# Out:
# 시작시작시작
# plastic start
# 2022-08-22
# 2022-08-22
# 2022-07-23
# {'endDate': '2022-08-28',
#  'results': [{'data': [{'period': '2022-07-18', 'ratio': 100},
#                        {'period': '2022-07-25', 'ratio': 79.48717},
#                        {'period': '2022-08-01', 'ratio': 54.87179},
#                        {'period': '2022-08-08', 'ratio': 57.82051},
#                        {'period': '2022-08-15', 'ratio': 60.64102},
#                        {'period': '2022-08-22', 'ratio': 70.51282}],
#               'keywords': ['생분해플라스틱'],
#               'title': '생분해플라스틱'}],
#  'startDate': '2022-07-18',
#  'timeUnit': 'week'}
# {'endDate': '2022-08-28',
#  'results': [{'data': [{'period': '2022-07-18', 'ratio': 72.87234},
#                        {'period': '2022-07-25', 'ratio': 61.70212},
#                        {'period': '2022-08-01', 'ratio': 56.91489},
#                        {'period': '2022-08-08', 'ratio': 80.85106},
#                        {'period': '2022-08-15', 'ratio': 77.12765},
#                        {'period': '2022-08-22', 'ratio': 100}],
#               'keywords': ['친환경선물'],
#               'title': '친환경선물'}],
#  'startDate': '2022-07-18',
#  'timeUnit': 'week'}
# {'endDate': '2022-08-28',
#  'results': [{'data': [{'period': '2022-07-18', 'ratio': 100},
#                        {'period': '2022-07-25', 'ratio': 46.12546},
#                        {'period': '2022-08-01', 'ratio': 45.20295},
#                        {'period': '2022-08-08', 'ratio': 50.27675},
#                        {'period': '2022-08-15', 'ratio': 88.83763},
#                        {'period': '2022-08-22', 'ratio': 85.05535}],
#               'keywords': ['바이오플라스틱'],
#               'title': '바이오플라스틱'}],
#  'startDate': '2022-07-18',
#  'timeUnit': 'week'}
# {'endDate': '2022-08-28',
#  'results': [{'data': [{'period': '2022-07-18', 'ratio': 64.18113},
#                        {'period': '2022-07-25', 'ratio': 47.3272},
#                        {'period': '2022-08-01', 'ratio': 48.00817},
#                        {'period': '2022-08-08', 'ratio': 47.3272},
#                        {'period': '2022-08-15', 'ratio': 54.03472},
#                        {'period': '2022-08-22', 'ratio': 100}],
#               'keywords': ['지구의날'],
#               'title': '지구의날'}],
#  'startDate': '2022-07-18',
#  'timeUnit': 'week'}
# {'endDate': '2022-08-28',
#  'results': [{'data': [{'period': '2022-07-18', 'ratio': 90.19522},
#                        {'period': '2022-07-25', 'ratio': 77.10773},
#                        {'period': '2022-08-01', 'ratio': 75.18438},
#                        {'period': '2022-08-08', 'ratio': 100},
#                        {'period': '2022-08-15', 'ratio': 91.85827},
#                        {'period': '2022-08-22', 'ratio': 98.59725}],
#               'keywords': ['제로웨이스트'],
#               'title': '제로웨이스트'}],
#  'startDate': '2022-07-18',
#  'timeUnit': 'week'}
# {'endDate': '2022-08-28',
#  'results': [{'data': [{'period': '2022-07-18', 'ratio': 49.31034},
#                        {'period': '2022-07-25', 'ratio': 40.34482},
#                        {'period': '2022-08-01', 'ratio': 68.62068},
#                        {'period': '2022-08-08', 'ratio': 100},
#                        {'period': '2022-08-15', 'ratio': 58.27586},
#                        {'period': '2022-08-22', 'ratio': 68.27586}],
#               'keywords': ['재생플라스틱'],
#               'title': '재생플라스틱'}],
#  'startDate': '2022-07-18',
#  'timeUnit': 'week'}
# {'endDate': '2022-08-28',
#  'results': [{'data': [{'period': '2022-07-18', 'ratio': 60.81424},
#                        {'period': '2022-07-25', 'ratio': 69.97455},
#                        {'period': '2022-08-01', 'ratio': 61.5776},
#                        {'period': '2022-08-08', 'ratio': 59.28753},
#                        {'period': '2022-08-15', 'ratio': 62.59541},
#                        {'period': '2022-08-22', 'ratio': 100}],
#               'keywords': ['친환경브랜드'],
#               'title': '친환경브랜드'}],
#  'startDate': '2022-07-18',
#  'timeUnit': 'week'}
# {'endDate': '2022-08-28',
#  'results': [{'data': [{'period': '2022-07-18', 'ratio': 75.31133},
#                        {'period': '2022-07-25', 'ratio': 82.87671},
#                        {'period': '2022-08-01', 'ratio': 77.50622},
#                        {'period': '2022-08-08', 'ratio': 93.78891},
#                        {'period': '2022-08-15', 'ratio': 95.84371},
#                        {'period': '2022-08-22', 'ratio': 100}],
#               'keywords': ['샴푸바'],
#               'title': '샴푸바'}],
#  'startDate': '2022-07-18',
#  'timeUnit': 'week'}
# {'endDate': '2022-08-28',
#  'results': [{'data': [{'period': '2022-07-18', 'ratio': 92.98642},
#                        {'period': '2022-07-25', 'ratio': 85.06787},
#                        {'period': '2022-08-01', 'ratio': 64.25339},
#                        {'period': '2022-08-08', 'ratio': 67.8733},
#                        {'period': '2022-08-15', 'ratio': 100},
#                        {'period': '2022-08-22', 'ratio': 83.7104}],
#               'keywords': ['친환경플라스틱'],
#               'title': '친환경플라스틱'}],
#  'startDate': '2022-07-18',
#  'timeUnit': 'week'}
# {'endDate': '2022-08-28',
#  'results': [{'data': [{'period': '2022-08-08', 'ratio': 100},
#                        {'period': '2022-08-22', 'ratio': 50}],
#               'keywords': ['미세플라스틱없는치약'],
#               'title': '미세플라스틱없는치약'}],
#  'startDate': '2022-07-18',
#  'timeUnit': 'week'}
# {'endDate': '2022-08-28',
#  'results': [{'data': [{'period': '2022-08-08', 'ratio': 100},
#                        {'period': '2022-08-22', 'ratio': 37.5}],
#               'keywords': ['미세플라스틱치약'],
#               'title': '미세플라스틱치약'}],
#  'startDate': '2022-07-18',
#  'timeUnit': 'week'}
# {'endDate': '2022-08-28',
#  'results': [{'data': [{'period': '2022-07-18', 'ratio': 95.56048},
#                        {'period': '2022-07-25', 'ratio': 81.96448},
#                        {'period': '2022-08-01', 'ratio': 81.52053},
#                        {'period': '2022-08-08', 'ratio': 76.3041},
#                        {'period': '2022-08-15', 'ratio': 82.74139},
#                        {'period': '2022-08-22', 'ratio': 100}],
#               'keywords': ['실리콘빨대'],
#               'title': '실리콘빨대'}],
#  'startDate': '2022-07-18',
#  'timeUnit': 'week'}
# {'endDate': '2022-08-28',
#  'results': [{'data': [{'period': '2022-07-18', 'ratio': 77.68643},
#                        {'period': '2022-07-25', 'ratio': 59.42454},
#                        {'period': '2022-08-01', 'ratio': 61.0687},
#                        {'period': '2022-08-08', 'ratio': 68.99588},
#                        {'period': '2022-08-15', 'ratio': 81.56194},
#                        {'period': '2022-08-22', 'ratio': 100}],
#               'keywords': ['업사이클링'],
#               'title': '업사이클링'}],
#  'startDate': '2022-07-18',
#  'timeUnit': 'week'}
# {'endDate': '2022-08-28',
#  'results': [{'data': [{'period': '2022-07-18', 'ratio': 98.24561},
#                        {'period': '2022-07-25', 'ratio': 80.70175},
#                        {'period': '2022-08-01', 'ratio': 43.85964},
#                        {'period': '2022-08-08', 'ratio': 100},
#                        {'period': '2022-08-15', 'ratio': 98.24561},
#                        {'period': '2022-08-22', 'ratio': 54.38596}],
#               'keywords': ['플라스틱프리'],
#               'title': '플라스틱프리'}],
#  'startDate': '2022-07-18',
#  'timeUnit': 'week'}
# {'endDate': '2022-08-28',
#  'results': [{'data': [{'period': '2022-07-18', 'ratio': 90.75444},
#                        {'period': '2022-07-25', 'ratio': 76.9255},
#                        {'period': '2022-08-01', 'ratio': 88.54937},
#                        {'period': '2022-08-08', 'ratio': 77.91778},
#                        {'period': '2022-08-15', 'ratio': 100},
#                        {'period': '2022-08-22', 'ratio': 99.48023}],
#               'keywords': ['천연수세미'],
#               'title': '천연수세미'}],
#  'startDate': '2022-07-18',
#  'timeUnit': 'week'}
# {'endDate': '2022-08-28',
#  'results': [{'data': [{'period': '2022-07-18', 'ratio': 40.90909},
#                        {'period': '2022-07-25', 'ratio': 31.81818},
#                        {'period': '2022-08-01', 'ratio': 63.63636},
#                        {'period': '2022-08-08', 'ratio': 100},
#                        {'period': '2022-08-15', 'ratio': 100},
#                        {'period': '2022-08-22', 'ratio': 31.81818}],
#               'keywords': ['친환경쇼핑몰'],
#               'title': '친환경쇼핑몰'}],
#  'startDate': '2022-07-18',
#  'timeUnit': 'week'}
# {'endDate': '2022-08-28',
#  'results': [{'data': [{'period': '2022-07-18', 'ratio': 100},
#                        {'period': '2022-07-25', 'ratio': 85.20047},
#                        {'period': '2022-08-01', 'ratio': 79.42216},
#                        {'period': '2022-08-08', 'ratio': 75.58962},
#                        {'period': '2022-08-15', 'ratio': 73.67334},
#                        {'period': '2022-08-22', 'ratio': 90.65448}],
#               'keywords': ['양말목공예'],
#               'title': '양말목공예'}],
#  'startDate': '2022-07-18',
#  'timeUnit': 'week'}
# {'endDate': '2022-08-28',
#  'results': [{'data': [{'period': '2022-07-18', 'ratio': 68.51361},
#                        {'period': '2022-07-25', 'ratio': 100},
#                        {'period': '2022-08-01', 'ratio': 75.64296},
#                        {'period': '2022-08-08', 'ratio': 96.65279},
#                        {'period': '2022-08-15', 'ratio': 59.05824},
#                        {'period': '2022-08-22', 'ratio': 79.236}],
#               'keywords': ['고체치약'],
#               'title': '고체치약'}],
#  'startDate': '2022-07-18',
#  'timeUnit': 'week'}
# {'endDate': '2022-08-28',
#  'results': [{'data': [], 'keywords': ['도전!플라스틱제로'], 'title': '도전!플라스틱제로'}],
#  'startDate': '2022-07-18',
#  'timeUnit': 'week'}
# {'endDate': '2022-08-28',
#  'results': [{'data': [{'period': '2022-07-18', 'ratio': 89.85507},
#                        {'period': '2022-07-25', 'ratio': 28.62318},
#                        {'period': '2022-08-01', 'ratio': 27.89855},
#                        {'period': '2022-08-08', 'ratio': 33.69565},
#                        {'period': '2022-08-15', 'ratio': 63.04347},
#                        {'period': '2022-08-22', 'ratio': 100}],
#               'keywords': ['플라스틱줄이기'],
#               'title': '플라스틱줄이기'}],
#  'startDate': '2022-07-18',
#  'timeUnit': 'week'}
# {'endDate': '2022-08-28',
#  'results': [{'data': [{'period': '2022-07-18', 'ratio': 63.96363},
#                        {'period': '2022-07-25', 'ratio': 64.07272},
#                        {'period': '2022-08-01', 'ratio': 85.23636},
#                        {'period': '2022-08-08', 'ratio': 100},
#                        {'period': '2022-08-15', 'ratio': 93.45454},
#                        {'period': '2022-08-22', 'ratio': 77.16363}],
#               'keywords': ['대나무칫솔'],
#               'title': '대나무칫솔'}],
#  'startDate': '2022-07-18',
#  'timeUnit': 'week'}
# {'endDate': '2022-08-28',
#  'results': [{'data': [{'period': '2022-07-18', 'ratio': 88.43537},
#                        {'period': '2022-07-25', 'ratio': 82.76643},
#                        {'period': '2022-08-01', 'ratio': 84.12698},
#                        {'period': '2022-08-08', 'ratio': 98.63945},
#                        {'period': '2022-08-15', 'ratio': 94.33106},
#                        {'period': '2022-08-22', 'ratio': 100}],
#               'keywords': ['친환경칫솔'],
#               'title': '친환경칫솔'}],
#  'startDate': '2022-07-18',
#  'timeUnit': 'week'}
# {'endDate': '2022-08-28',
#  'results': [{'data': [{'period': '2022-07-18', 'ratio': 100},
#                        {'period': '2022-07-25', 'ratio': 58.06831},
#                        {'period': '2022-08-01', 'ratio': 48.64546},
#                        {'period': '2022-08-08', 'ratio': 44.75853},
#                        {'period': '2022-08-15', 'ratio': 66.90223},
#                        {'period': '2022-08-22', 'ratio': 86.69022}],
#               'keywords': ['생분해성플라스틱'],
#               'title': '생분해성플라스틱'}],
#  'startDate': '2022-07-18',
#  'timeUnit': 'week'}
# {'endDate': '2022-08-28',
#  'results': [{'data': [{'period': '2022-07-18', 'ratio': 51.80722},
#                        {'period': '2022-07-25', 'ratio': 71.08433},
#                        {'period': '2022-08-01', 'ratio': 50.6024},
#                        {'period': '2022-08-08', 'ratio': 100},
#                        {'period': '2022-08-15', 'ratio': 77.10843},
#                        {'period': '2022-08-22', 'ratio': 63.85542}],
#               'keywords': ['플라스틱제로'],
#               'title': '플라스틱제로'}],
#  'startDate': '2022-07-18',
#  'timeUnit': 'week'}
# {'endDate': '2022-08-28',
#  'results': [{'data': [{'period': '2022-07-18', 'ratio': 88.74435},
#                        {'period': '2022-07-25', 'ratio': 85.46588},
#                        {'period': '2022-08-01', 'ratio': 92.07592},
#                        {'period': '2022-08-08', 'ratio': 93.42978},
#                        {'period': '2022-08-15', 'ratio': 100},
#                        {'period': '2022-08-22', 'ratio': 98.53995}],
#               'keywords': ['미니멀라이프'],
#               'title': '미니멀라이프'}],
#  'startDate': '2022-07-18',
#  'timeUnit': 'week'}
# {'endDate': '2022-08-28',
#  'results': [{'data': [{'period': '2022-07-18', 'ratio': 100},
#                        {'period': '2022-07-25', 'ratio': 81.27413},
#                        {'period': '2022-08-01', 'ratio': 93.05019},
#                        {'period': '2022-08-08', 'ratio': 95.55984},
#                        {'period': '2022-08-15', 'ratio': 88.80308},
#                        {'period': '2022-08-22', 'ratio': 88.61003}],
#               'keywords': ['밀랍랩'],
#               'title': '밀랍랩'}],
#  'startDate': '2022-07-18',
#  'timeUnit': 'week'}
# {'endDate': '2022-08-28',
#  'results': [{'data': [{'period': '2022-07-18', 'ratio': 100},
#                        {'period': '2022-07-25', 'ratio': 64.9315},
#                        {'period': '2022-08-01', 'ratio': 59.86301},
#                        {'period': '2022-08-08', 'ratio': 48.08219},
#                        {'period': '2022-08-15', 'ratio': 68.63013},
#                        {'period': '2022-08-22', 'ratio': 73.69863}],
#               'keywords': ['업사이클링제품'],
#               'title': '업사이클링제품'}],
#  'startDate': '2022-07-18',
#  'timeUnit': 'week'}
#      title      period
# 0  플라스틱줄이기  2022-08-22
# 1    실리콘빨대  2022-08-22
# 2    친환경칫솔  2022-08-22
# 3     지구의날  2022-08-22
# 4   친환경브랜드  2022-08-22
# 5      샴푸바  2022-08-22
# 6    친환경선물  2022-08-22
# 7    업사이클링  2022-08-22
# 8    천연수세미  2022-08-22
# 9   제로웨이스트  2022-08-22
# plastic success commit
# vegan start
# {'endDate': '2022-08-28',
#  'results': [{'data': [{'period': '2022-07-18', 'ratio': 30.15873},
#                        {'period': '2022-07-25', 'ratio': 21.16402},
#                        {'period': '2022-08-01', 'ratio': 33.86243},
#                        {'period': '2022-08-08', 'ratio': 30.15873},
#                        {'period': '2022-08-15', 'ratio': 100},
#                        {'period': '2022-08-22', 'ratio': 25.39682}],
#               'keywords': ['비건박람회'],
#               'title': '비건박람회'}],
#  'startDate': '2022-07-18',
#  'timeUnit': 'week'}
# {'endDate': '2022-08-28',
#  'results': [{'data': [{'period': '2022-07-18', 'ratio': 86.0215},
#                        {'period': '2022-07-25', 'ratio': 72.04301},
#                        {'period': '2022-08-01', 'ratio': 94.62365},
#                        {'period': '2022-08-08', 'ratio': 84.94623},
#                        {'period': '2022-08-15', 'ratio': 84.94623},
#                        {'period': '2022-08-22', 'ratio': 100}],
#               'keywords': ['채식단백질'],
#               'title': '채식단백질'}],
#  'startDate': '2022-07-18',
#  'timeUnit': 'week'}
# {'endDate': '2022-08-28',
#  'results': [{'data': [{'period': '2022-07-18', 'ratio': 84.18079},
#                        {'period': '2022-07-25', 'ratio': 100},
#                        {'period': '2022-08-01', 'ratio': 90.5838},
#                        {'period': '2022-08-08', 'ratio': 86.629},
#                        {'period': '2022-08-15', 'ratio': 88.70056},
#                        {'period': '2022-08-22', 'ratio': 93.40866}],
#               'keywords': ['비건빵집'],
#               'title': '비건빵집'}],
#  'startDate': '2022-07-18',
#  'timeUnit': 'week'}
# {'endDate': '2022-08-28',
#  'results': [{'data': [{'period': '2022-07-18', 'ratio': 89.42731},
#                        {'period': '2022-07-25', 'ratio': 100},
#                        {'period': '2022-08-01', 'ratio': 96.47577},
#                        {'period': '2022-08-08', 'ratio': 95.59471},
#                        {'period': '2022-08-15', 'ratio': 94.27312},
#                        {'period': '2022-08-22', 'ratio': 99.55947}],
#               'keywords': ['채식라면'],
#               'title': '채식라면'}],
#  'startDate': '2022-07-18',
#  'timeUnit': 'week'}
# {'endDate': '2022-08-28',
#  'results': [{'data': [{'period': '2022-07-18', 'ratio': 86.94516},
#                        {'period': '2022-07-25', 'ratio': 80.88772},
#                        {'period': '2022-08-01', 'ratio': 86.26631},
#                        {'period': '2022-08-08', 'ratio': 84.43864},
#                        {'period': '2022-08-15', 'ratio': 95.50913},
#                        {'period': '2022-08-22', 'ratio': 100}],
#               'keywords': ['반찬메뉴'],
#               'title': '반찬메뉴'}],
#  'startDate': '2022-07-18',
#  'timeUnit': 'week'}
# {'endDate': '2022-08-28',
#  'results': [{'data': [{'period': '2022-07-18', 'ratio': 69.90692},
#                        {'period': '2022-07-25', 'ratio': 100},
#                        {'period': '2022-08-01', 'ratio': 89.00594},
#                        {'period': '2022-08-08', 'ratio': 79.65356},
#                        {'period': '2022-08-15', 'ratio': 63.16571},
#                        {'period': '2022-08-22', 'ratio': 57.65899}],
#               'keywords': ['서울근교당일치기여행'],
#               'title': '서울근교당일치기여행'}],
#  'startDate': '2022-07-18',
#  'timeUnit': 'week'}
# {'endDate': '2022-08-28',
#  'results': [{'data': [{'period': '2022-07-18', 'ratio': 68.94865},
#                        {'period': '2022-07-25', 'ratio': 78.2396},
#                        {'period': '2022-08-01', 'ratio': 100},
#                        {'period': '2022-08-08', 'ratio': 91.19804},
#                        {'period': '2022-08-15', 'ratio': 81.41809},
#                        {'period': '2022-08-22', 'ratio': 84.10757}],
#               'keywords': ['채식부페'],
#               'title': '채식부페'}],
#  'startDate': '2022-07-18',
#  'timeUnit': 'week'}
# {'endDate': '2022-08-28',
#  'results': [{'data': [{'period': '2022-07-18', 'ratio': 62.0155},
#                        {'period': '2022-07-25', 'ratio': 44.18604},
#                        {'period': '2022-08-01', 'ratio': 82.94573},
#                        {'period': '2022-08-08', 'ratio': 100},
#                        {'period': '2022-08-15', 'ratio': 81.39534},
#                        {'period': '2022-08-22', 'ratio': 82.94573}],
#               'keywords': ['야채식단'],
#               'title': '야채식단'}],
#  'startDate': '2022-07-18',
#  'timeUnit': 'week'}
# {'endDate': '2022-08-28',
#  'results': [{'data': [{'period': '2022-07-18', 'ratio': 90.5908},
#                        {'period': '2022-07-25', 'ratio': 85.12035},
#                        {'period': '2022-08-01', 'ratio': 94.52954},
#                        {'period': '2022-08-08', 'ratio': 94.74835},
#                        {'period': '2022-08-15', 'ratio': 100},
#                        {'period': '2022-08-22', 'ratio': 95.18599}],
#               'keywords': ['비건과자'],
#               'title': '비건과자'}],
#  'startDate': '2022-07-18',
#  'timeUnit': 'week'}
# {'endDate': '2022-08-28',
#  'results': [{'data': [{'period': '2022-07-18', 'ratio': 85.66654},
#                        {'period': '2022-07-25', 'ratio': 100},
#                        {'period': '2022-08-01', 'ratio': 91.68213},
#                        {'period': '2022-08-08', 'ratio': 79.98514},
#                        {'period': '2022-08-15', 'ratio': 79.83661},
#                        {'period': '2022-08-22', 'ratio': 80.95061}],
#               'keywords': ['비건베이커리'],
#               'title': '비건베이커리'}],
#  'startDate': '2022-07-18',
#  'timeUnit': 'week'}
# {'endDate': '2022-08-28',
#  'results': [{'data': [{'period': '2022-07-18', 'ratio': 55.40968},
#                        {'period': '2022-07-25', 'ratio': 100},
#                        {'period': '2022-08-01', 'ratio': 74.15374},
#                        {'period': '2022-08-08', 'ratio': 47.16861},
#                        {'period': '2022-08-15', 'ratio': 49.60455},
#                        {'period': '2022-08-22', 'ratio': 51.4236}],
#               'keywords': ['콩고기'],
#               'title': '콩고기'}],
#  'startDate': '2022-07-18',
#  'timeUnit': 'week'}
# {'endDate': '2022-08-28',
#  'results': [{'data': [{'period': '2022-07-18', 'ratio': 74.94824},
#                        {'period': '2022-07-25', 'ratio': 100},
#                        {'period': '2022-08-01', 'ratio': 84.26501},
#                        {'period': '2022-08-08', 'ratio': 74.94824},
#                        {'period': '2022-08-15', 'ratio': 71.63561},
#                        {'period': '2022-08-22', 'ratio': 78.88198}],
#               'keywords': ['비건버터'],
#               'title': '비건버터'}],
#  'startDate': '2022-07-18',
#  'timeUnit': 'week'}
# {'endDate': '2022-08-28',
#  'results': [{'data': [{'period': '2022-07-18', 'ratio': 47.82608},
#                        {'period': '2022-07-25', 'ratio': 75.36231},
#                        {'period': '2022-08-01', 'ratio': 100},
#                        {'period': '2022-08-08', 'ratio': 79.71014},
#                        {'period': '2022-08-15', 'ratio': 49.27536},
#                        {'period': '2022-08-22', 'ratio': 81.15942}],
#               'keywords': ['부산채식'],
#               'title': '부산채식'}],
#  'startDate': '2022-07-18',
#  'timeUnit': 'week'}
# {'endDate': '2022-08-28',
#  'results': [{'data': [{'period': '2022-07-18', 'ratio': 97.67441},
#                        {'period': '2022-07-25', 'ratio': 78.72093},
#                        {'period': '2022-08-01', 'ratio': 90.93023},
#                        {'period': '2022-08-08', 'ratio': 87.44186},
#                        {'period': '2022-08-15', 'ratio': 100},
#                        {'period': '2022-08-22', 'ratio': 96.16279}],
#               'keywords': ['채식식단'],
#               'title': '채식식단'}],
#  'startDate': '2022-07-18',
#  'timeUnit': 'week'}
# {'endDate': '2022-08-28',
#  'results': [{'data': [{'period': '2022-07-18', 'ratio': 67.26726},
#                        {'period': '2022-07-25', 'ratio': 63.96396},
#                        {'period': '2022-08-01', 'ratio': 100},
#                        {'period': '2022-08-08', 'ratio': 84.08408},
#                        {'period': '2022-08-15', 'ratio': 79.87987},
#                        {'period': '2022-08-22', 'ratio': 81.98198}],
#               'keywords': ['채식만두'],
#               'title': '채식만두'}],
#  'startDate': '2022-07-18',
#  'timeUnit': 'week'}
# {'endDate': '2022-08-28',
#  'results': [{'data': [{'period': '2022-07-18', 'ratio': 100},
#                        {'period': '2022-07-25', 'ratio': 84.27672},
#                        {'period': '2022-08-01', 'ratio': 75},
#                        {'period': '2022-08-08', 'ratio': 88.83647},
#                        {'period': '2022-08-15', 'ratio': 82.38993},
#                        {'period': '2022-08-22', 'ratio': 84.74842}],
#               'keywords': ['비건라면'],
#               'title': '비건라면'}],
#  'startDate': '2022-07-18',
#  'timeUnit': 'week'}
# {'endDate': '2022-08-28',
#  'results': [{'data': [{'period': '2022-07-18', 'ratio': 100},
#                        {'period': '2022-07-25', 'ratio': 90.01996},
#                        {'period': '2022-08-01', 'ratio': 86.82634},
#                        {'period': '2022-08-08', 'ratio': 79.84031},
#                        {'period': '2022-08-15', 'ratio': 74.25149},
#                        {'period': '2022-08-22', 'ratio': 85.22954}],
#               'keywords': ['비건인증'],
#               'title': '비건인증'}],
#  'startDate': '2022-07-18',
#  'timeUnit': 'week'}
# {'endDate': '2022-08-28',
#  'results': [{'data': [{'period': '2022-07-18', 'ratio': 95.17241},
#                        {'period': '2022-07-25', 'ratio': 76.55172},
#                        {'period': '2022-08-01', 'ratio': 95.86206},
#                        {'period': '2022-08-08', 'ratio': 84.13793},
#                        {'period': '2022-08-15', 'ratio': 100},
#                        {'period': '2022-08-22', 'ratio': 84.13793}],
#               'keywords': ['생채식'],
#               'title': '생채식'}],
#  'startDate': '2022-07-18',
#  'timeUnit': 'week'}
# {'endDate': '2022-08-28',
#  'results': [{'data': [{'period': '2022-07-18', 'ratio': 86.81818},
#                        {'period': '2022-07-25', 'ratio': 75.90909},
#                        {'period': '2022-08-01', 'ratio': 100},
#                        {'period': '2022-08-08', 'ratio': 86.36363},
#                        {'period': '2022-08-15', 'ratio': 79.54545},
#                        {'period': '2022-08-22', 'ratio': 62.5}],
#               'keywords': ['채식뷔페'],
#               'title': '채식뷔페'}],
#  'startDate': '2022-07-18',
#  'timeUnit': 'week'}
# {'endDate': '2022-08-28',
#  'results': [{'data': [{'period': '2022-07-18', 'ratio': 71.85978},
#                        {'period': '2022-07-25', 'ratio': 71.95715},
#                        {'period': '2022-08-01', 'ratio': 72.93086},
#                        {'period': '2022-08-08', 'ratio': 85.10223},
#                        {'period': '2022-08-15', 'ratio': 100},
#                        {'period': '2022-08-22', 'ratio': 86.46543}],
#               'keywords': ['비건쿠키'],
#               'title': '비건쿠키'}],
#  'startDate': '2022-07-18',
#  'timeUnit': 'week'}
# {'endDate': '2022-08-28',
#  'results': [{'data': [{'period': '2022-07-18', 'ratio': 98.50694},
#                        {'period': '2022-07-25', 'ratio': 100},
#                        {'period': '2022-08-01', 'ratio': 98.90972},
#                        {'period': '2022-08-08', 'ratio': 85.375},
#                        {'period': '2022-08-15', 'ratio': 94.10416},
#                        {'period': '2022-08-22', 'ratio': 89.80555}],
#               'keywords': ['신사역맛집'],
#               'title': '신사역맛집'}],
#  'startDate': '2022-07-18',
#  'timeUnit': 'week'}
# {'endDate': '2022-08-28',
#  'results': [{'data': [{'period': '2022-07-18', 'ratio': 100},
#                        {'period': '2022-07-25', 'ratio': 81.88976},
#                        {'period': '2022-08-01', 'ratio': 86.02362},
#                        {'period': '2022-08-08', 'ratio': 75.19685},
#                        {'period': '2022-08-15', 'ratio': 80.11811},
#                        {'period': '2022-08-22', 'ratio': 69.88188}],
#               'keywords': ['비건김밥'],
#               'title': '비건김밥'}],
#  'startDate': '2022-07-18',
#  'timeUnit': 'week'}
# {'endDate': '2022-08-28',
#  'results': [{'data': [{'period': '2022-07-18', 'ratio': 97.59967},
#                        {'period': '2022-07-25', 'ratio': 99.43043},
#                        {'period': '2022-08-01', 'ratio': 94.71114},
#                        {'period': '2022-08-08', 'ratio': 96.86737},
#                        {'period': '2022-08-15', 'ratio': 100},
#                        {'period': '2022-08-22', 'ratio': 98.25061}],
#               'keywords': ['비건빵'],
#               'title': '비건빵'}],
#  'startDate': '2022-07-18',
#  'timeUnit': 'week'}
# {'endDate': '2022-08-28',
#  'results': [{'data': [{'period': '2022-07-18', 'ratio': 95.36423},
#                        {'period': '2022-07-25', 'ratio': 83.77483},
#                        {'period': '2022-08-01', 'ratio': 100},
#                        {'period': '2022-08-08', 'ratio': 85.76158},
#                        {'period': '2022-08-15', 'ratio': 82.78145},
#                        {'period': '2022-08-22', 'ratio': 98.34437}],
#               'keywords': ['채식한끼'],
#               'title': '채식한끼'}],
#  'startDate': '2022-07-18',
#  'timeUnit': 'week'}
# {'endDate': '2022-08-28',
#  'results': [{'data': [{'period': '2022-07-18', 'ratio': 100},
#                        {'period': '2022-07-25', 'ratio': 91.92399},
#                        {'period': '2022-08-01', 'ratio': 82.66033},
#                        {'period': '2022-08-08', 'ratio': 87.17339},
#                        {'period': '2022-08-15', 'ratio': 90.97387},
#                        {'period': '2022-08-22', 'ratio': 84.79809}],
#               'keywords': ['채식식당'],
#               'title': '채식식당'}],
#  'startDate': '2022-07-18',
#  'timeUnit': 'week'}
# {'endDate': '2022-08-28',
#  'results': [{'data': [{'period': '2022-07-18', 'ratio': 88.21263},
#                        {'period': '2022-07-25', 'ratio': 82.43451},
#                        {'period': '2022-08-01', 'ratio': 84.59167},
#                        {'period': '2022-08-08', 'ratio': 82.35747},
#                        {'period': '2022-08-15', 'ratio': 100},
#                        {'period': '2022-08-22', 'ratio': 92.44992}],
#               'keywords': ['채식'],
#               'title': '채식'}],
#  'startDate': '2022-07-18',
#  'timeUnit': 'week'}
# {'endDate': '2022-08-28',
#  'results': [{'data': [{'period': '2022-07-18', 'ratio': 100},
#                        {'period': '2022-07-25', 'ratio': 66.65462},
#                        {'period': '2022-08-01', 'ratio': 63.18641},
#                        {'period': '2022-08-08', 'ratio': 51.48121},
#                        {'period': '2022-08-15', 'ratio': 56.25},
#                        {'period': '2022-08-22', 'ratio': 61.88583}],
#               'keywords': ['대체육'],
#               'title': '대체육'}],
#  'startDate': '2022-07-18',
#  'timeUnit': 'week'}
# {'endDate': '2022-08-28',
#  'results': [{'data': [{'period': '2022-07-18', 'ratio': 83.17272},
#                        {'period': '2022-07-25', 'ratio': 84.72942},
#                        {'period': '2022-08-01', 'ratio': 89.17716},
#                        {'period': '2022-08-08', 'ratio': 83.83988},
#                        {'period': '2022-08-15', 'ratio': 89.62194},
#                        {'period': '2022-08-22', 'ratio': 100}],
#               'keywords': ['사찰음식'],
#               'title': '사찰음식'}],
#  'startDate': '2022-07-18',
#  'timeUnit': 'week'}
# {'endDate': '2022-08-28',
#  'results': [{'data': [{'period': '2022-07-18', 'ratio': 100},
#                        {'period': '2022-07-25', 'ratio': 69.50549},
#                        {'period': '2022-08-01', 'ratio': 65.24725},
#                        {'period': '2022-08-08', 'ratio': 66.62087},
#                        {'period': '2022-08-15', 'ratio': 73.90109},
#                        {'period': '2022-08-22', 'ratio': 73.48901}],
#               'keywords': ['비건치즈'],
#               'title': '비건치즈'}],
#  'startDate': '2022-07-18',
#  'timeUnit': 'week'}
# {'endDate': '2022-08-28',
#  'results': [{'data': [{'period': '2022-07-18', 'ratio': 88.71265},
#                        {'period': '2022-07-25', 'ratio': 100},
#                        {'period': '2022-08-01', 'ratio': 98.57952},
#                        {'period': '2022-08-08', 'ratio': 88.38779},
#                        {'period': '2022-08-15', 'ratio': 86.18383},
#                        {'period': '2022-08-22', 'ratio': 75.80737}],
#               'keywords': ['전시'],
#               'title': '전시'}],
#  'startDate': '2022-07-18',
#  'timeUnit': 'week'}
# {'endDate': '2022-08-28',
#  'results': [{'data': [{'period': '2022-07-18', 'ratio': 95.71663},
#                        {'period': '2022-07-25', 'ratio': 85.33772},
#                        {'period': '2022-08-01', 'ratio': 88.30313},
#                        {'period': '2022-08-08', 'ratio': 85.00823},
#                        {'period': '2022-08-15', 'ratio': 99.17627},
#                        {'period': '2022-08-22', 'ratio': 100}],
#               'keywords': ['비건만두'],
#               'title': '비건만두'}],
#  'startDate': '2022-07-18',
#  'timeUnit': 'week'}
# {'endDate': '2022-08-28',
#  'results': [{'data': [{'period': '2022-07-18', 'ratio': 87.14733},
#                        {'period': '2022-07-25', 'ratio': 76.8025},
#                        {'period': '2022-08-01', 'ratio': 72.41379},
#                        {'period': '2022-08-08', 'ratio': 85.57993},
#                        {'period': '2022-08-15', 'ratio': 84.32601},
#                        {'period': '2022-08-22', 'ratio': 100}],
#               'keywords': ['채식주의'],
#               'title': '채식주의'}],
#  'startDate': '2022-07-18',
#  'timeUnit': 'week'}
# {'endDate': '2022-08-28',
#  'results': [{'data': [{'period': '2022-07-18', 'ratio': 92.99191},
#                        {'period': '2022-07-25', 'ratio': 100},
#                        {'period': '2022-08-01', 'ratio': 94.33962},
#                        {'period': '2022-08-08', 'ratio': 99.19137},
#                        {'period': '2022-08-15', 'ratio': 87.87061},
#                        {'period': '2022-08-22', 'ratio': 98.92183}],
#               'keywords': ['비건요리'],
#               'title': '비건요리'}],
#  'startDate': '2022-07-18',
#  'timeUnit': 'week'}
# {'endDate': '2022-08-28',
#  'results': [{'data': [{'period': '2022-07-18', 'ratio': 77.01711},
#                        {'period': '2022-07-25', 'ratio': 78.7286},
#                        {'period': '2022-08-01', 'ratio': 81.66259},
#                        {'period': '2022-08-08', 'ratio': 88.99755},
#                        {'period': '2022-08-15', 'ratio': 100},
#                        {'period': '2022-08-22', 'ratio': 77.75061}],
#               'keywords': ['비건스콘'],
#               'title': '비건스콘'}],
#  'startDate': '2022-07-18',
#  'timeUnit': 'week'}
# {'endDate': '2022-08-28',
#  'results': [{'data': [{'period': '2022-07-18', 'ratio': 86.01216},
#                        {'period': '2022-07-25', 'ratio': 63.16246},
#                        {'period': '2022-08-01', 'ratio': 100},
#                        {'period': '2022-08-08', 'ratio': 89.13987},
#                        {'period': '2022-08-15', 'ratio': 70.59079},
#                        {'period': '2022-08-22', 'ratio': 72.84969}],
#               'keywords': ['비욘드미트'],
#               'title': '비욘드미트'}],
#  'startDate': '2022-07-18',
#  'timeUnit': 'week'}
# {'endDate': '2022-08-28',
#  'results': [{'data': [{'period': '2022-07-18', 'ratio': 66.94214},
#                        {'period': '2022-07-25', 'ratio': 55.3719},
#                        {'period': '2022-08-01', 'ratio': 57.85123},
#                        {'period': '2022-08-08', 'ratio': 57.02479},
#                        {'period': '2022-08-15', 'ratio': 100},
#                        {'period': '2022-08-22', 'ratio': 80.99173}],
#               'keywords': ['장담그기'],
#               'title': '장담그기'}],
#  'startDate': '2022-07-18',
#  'timeUnit': 'week'}
# {'endDate': '2022-08-28',
#  'results': [{'data': [{'period': '2022-07-18', 'ratio': 72.51184},
#                        {'period': '2022-07-25', 'ratio': 68.24644},
#                        {'period': '2022-08-01', 'ratio': 100},
#                        {'period': '2022-08-08', 'ratio': 54.02843},
#                        {'period': '2022-08-15', 'ratio': 79.62085},
#                        {'period': '2022-08-22', 'ratio': 91.46919}],
#               'keywords': ['현미채식'],
#               'title': '현미채식'}],
#  'startDate': '2022-07-18',
#  'timeUnit': 'week'}
# {'endDate': '2022-08-28',
#  'results': [{'data': [{'period': '2022-07-18', 'ratio': 70.35647},
#                        {'period': '2022-07-25', 'ratio': 61.81988},
#                        {'period': '2022-08-01', 'ratio': 62.85178},
#                        {'period': '2022-08-08', 'ratio': 58.53658},
#                        {'period': '2022-08-15', 'ratio': 66.22889},
#                        {'period': '2022-08-22', 'ratio': 100}],
#               'keywords': ['비건레더'],
#               'title': '비건레더'}],
#  'startDate': '2022-07-18',
#  'timeUnit': 'week'}
# {'endDate': '2022-08-28',
#  'results': [{'data': [{'period': '2022-07-18', 'ratio': 91.46608},
#                        {'period': '2022-07-25', 'ratio': 85.55798},
#                        {'period': '2022-08-01', 'ratio': 83.3698},
#                        {'period': '2022-08-08', 'ratio': 70.2407},
#                        {'period': '2022-08-15', 'ratio': 78.55579},
#                        {'period': '2022-08-22', 'ratio': 100}],
#               'keywords': ['비건도시락'],
#               'title': '비건도시락'}],
#  'startDate': '2022-07-18',
#  'timeUnit': 'week'}
# {'endDate': '2022-08-28',
#  'results': [{'data': [{'period': '2022-07-18', 'ratio': 67.63173},
#                        {'period': '2022-07-25', 'ratio': 59.20671},
#                        {'period': '2022-08-01', 'ratio': 59.46728},
#                        {'period': '2022-08-08', 'ratio': 74.26172},
#                        {'period': '2022-08-15', 'ratio': 100},
#                        {'period': '2022-08-22', 'ratio': 71.04806}],
#               'keywords': ['비건화장품'],
#               'title': '비건화장품'}],
#  'startDate': '2022-07-18',
#  'timeUnit': 'week'}
# {'endDate': '2022-08-28',
#  'results': [{'data': [{'period': '2022-07-18', 'ratio': 16.66666},
#                        {'period': '2022-07-25', 'ratio': 25},
#                        {'period': '2022-08-01', 'ratio': 30},
#                        {'period': '2022-08-08', 'ratio': 38.33333},
#                        {'period': '2022-08-15', 'ratio': 53.33333},
#                        {'period': '2022-08-22', 'ratio': 100}],
#               'keywords': ['김장체험'],
#               'title': '김장체험'}],
#  'startDate': '2022-07-18',
#  'timeUnit': 'week'}
# {'endDate': '2022-08-28',
#  'results': [{'data': [{'period': '2022-07-18', 'ratio': 93.07228},
#                        {'period': '2022-07-25', 'ratio': 82.83132},
#                        {'period': '2022-08-01', 'ratio': 78.31325},
#                        {'period': '2022-08-08', 'ratio': 77.40963},
#                        {'period': '2022-08-15', 'ratio': 92.16867},
#                        {'period': '2022-08-22', 'ratio': 100}],
#               'keywords': ['비건백'],
#               'title': '비건백'}],
#  'startDate': '2022-07-18',
#  'timeUnit': 'week'}
# {'endDate': '2022-08-28',
#  'results': [{'data': [{'period': '2022-07-18', 'ratio': 100},
#                        {'period': '2022-07-25', 'ratio': 94.1576},
#                        {'period': '2022-08-01', 'ratio': 84.91847},
#                        {'period': '2022-08-08', 'ratio': 80.23097},
#                        {'period': '2022-08-15', 'ratio': 81.25},
#                        {'period': '2022-08-22', 'ratio': 83.55978}],
#               'keywords': ['비건음식'],
#               'title': '비건음식'}],
#  'startDate': '2022-07-18',
#  'timeUnit': 'week'}
# {'endDate': '2022-08-28',
#  'results': [{'data': [{'period': '2022-07-18', 'ratio': 100},
#                        {'period': '2022-07-25', 'ratio': 77.21518},
#                        {'period': '2022-08-01', 'ratio': 53.16455},
#                        {'period': '2022-08-08', 'ratio': 58.95117},
#                        {'period': '2022-08-15', 'ratio': 65.46112},
#                        {'period': '2022-08-22', 'ratio': 67.0886}],
#               'keywords': ['비건식품'],
#               'title': '비건식품'}],
#  'startDate': '2022-07-18',
#  'timeUnit': 'week'}
# {'endDate': '2022-08-28',
#  'results': [{'data': [{'period': '2022-07-18', 'ratio': 100},
#                        {'period': '2022-07-25', 'ratio': 87.60724},
#                        {'period': '2022-08-01', 'ratio': 80.6244},
#                        {'period': '2022-08-08', 'ratio': 74.40419},
#                        {'period': '2022-08-15', 'ratio': 79.1468},
#                        {'period': '2022-08-22', 'ratio': 73.97521}],
#               'keywords': ['비건뜻'],
#               'title': '비건뜻'}],
#  'startDate': '2022-07-18',
#  'timeUnit': 'week'}
# {'endDate': '2022-08-28',
#  'results': [{'data': [{'period': '2022-07-18', 'ratio': 80.55995},
#                        {'period': '2022-07-25', 'ratio': 100},
#                        {'period': '2022-08-01', 'ratio': 99.69689},
#                        {'period': '2022-08-08', 'ratio': 54.70986},
#                        {'period': '2022-08-15', 'ratio': 57.60167},
#                        {'period': '2022-08-22', 'ratio': 54.88948}],
#               'keywords': ['서울가볼만한곳'],
#               'title': '서울가볼만한곳'}],
#  'startDate': '2022-07-18',
#  'timeUnit': 'week'}
# {'endDate': '2022-08-28',
#  'results': [{'data': [{'period': '2022-07-18', 'ratio': 100},
#                        {'period': '2022-07-25', 'ratio': 73.3167},
#                        {'period': '2022-08-01', 'ratio': 78.30423},
#                        {'period': '2022-08-08', 'ratio': 70.32418},
#                        {'period': '2022-08-15', 'ratio': 89.2768},
#                        {'period': '2022-08-22', 'ratio': 86.03491}],
#               'keywords': ['비건젤리'],
#               'title': '비건젤리'}],
#  'startDate': '2022-07-18',
#  'timeUnit': 'week'}
# {'endDate': '2022-08-28',
#  'results': [{'data': [{'period': '2022-07-18', 'ratio': 95.3009},
#                        {'period': '2022-07-25', 'ratio': 97.36603},
#                        {'period': '2022-08-01', 'ratio': 100},
#                        {'period': '2022-08-08', 'ratio': 82.10016},
#                        {'period': '2022-08-15', 'ratio': 84.90313},
#                        {'period': '2022-08-22', 'ratio': 83.10799}],
#               'keywords': ['강남맛집'],
#               'title': '강남맛집'}],
#  'startDate': '2022-07-18',
#  'timeUnit': 'week'}
# {'endDate': '2022-08-28',
#  'results': [{'data': [{'period': '2022-07-18', 'ratio': 88.3656},
#                        {'period': '2022-07-25', 'ratio': 100},
#                        {'period': '2022-08-01', 'ratio': 97.32626},
#                        {'period': '2022-08-08', 'ratio': 85.35357},
#                        {'period': '2022-08-15', 'ratio': 79.52516},
#                        {'period': '2022-08-22', 'ratio': 70.4463}],
#               'keywords': ['전시회'],
#               'title': '전시회'}],
#  'startDate': '2022-07-18',
#  'timeUnit': 'week'}
# {'endDate': '2022-08-28',
#  'results': [{'data': [{'period': '2022-07-18', 'ratio': 100},
#                        {'period': '2022-07-25', 'ratio': 92.66547},
#                        {'period': '2022-08-01', 'ratio': 88.38998},
#                        {'period': '2022-08-08', 'ratio': 92.79069},
#                        {'period': '2022-08-15', 'ratio': 99.24865},
#                        {'period': '2022-08-22', 'ratio': 97.45974}],
#               'keywords': ['선식'],
#               'title': '선식'}],
#  'startDate': '2022-07-18',
#  'timeUnit': 'week'}
# {'endDate': '2022-08-28',
#  'results': [{'data': [{'period': '2022-07-18', 'ratio': 78.90543},
#                        {'period': '2022-07-25', 'ratio': 98.8223},
#                        {'period': '2022-08-01', 'ratio': 73.98683},
#                        {'period': '2022-08-08', 'ratio': 86.11014},
#                        {'period': '2022-08-15', 'ratio': 78.8708},
#                        {'period': '2022-08-22', 'ratio': 100}],
#               'keywords': ['생식'],
#               'title': '생식'}],
#  'startDate': '2022-07-18',
#  'timeUnit': 'week'}
# {'endDate': '2022-08-28',
#  'results': [{'data': [{'period': '2022-07-18', 'ratio': 94.4186},
#                        {'period': '2022-07-25', 'ratio': 98.13953},
#                        {'period': '2022-08-01', 'ratio': 92.09302},
#                        {'period': '2022-08-08', 'ratio': 92.79069},
#                        {'period': '2022-08-15', 'ratio': 100},
#                        {'period': '2022-08-22', 'ratio': 95.34883}],
#               'keywords': ['비건가죽'],
#               'title': '비건가죽'}],
#  'startDate': '2022-07-18',
#  'timeUnit': 'week'}
# {'endDate': '2022-08-28',
#  'results': [{'data': [{'period': '2022-07-18', 'ratio': 40.32258},
#                        {'period': '2022-07-25', 'ratio': 79.03225},
#                        {'period': '2022-08-01', 'ratio': 75.80645},
#                        {'period': '2022-08-08', 'ratio': 95.16129},
#                        {'period': '2022-08-15', 'ratio': 62.90322},
#                        {'period': '2022-08-22', 'ratio': 100}],
#               'keywords': ['채식단계'],
#               'title': '채식단계'}],
#  'startDate': '2022-07-18',
#  'timeUnit': 'week'}
# {'endDate': '2022-08-28',
#  'results': [{'data': [{'period': '2022-07-18', 'ratio': 61.94029},
#                        {'period': '2022-07-25', 'ratio': 59.1791},
#                        {'period': '2022-08-01', 'ratio': 84.55223},
#                        {'period': '2022-08-08', 'ratio': 100},
#                        {'period': '2022-08-15', 'ratio': 78.13432},
#                        {'period': '2022-08-22', 'ratio': 66.86567}],
#               'keywords': ['보식'],
#               'title': '보식'}],
#  'startDate': '2022-07-18',
#  'timeUnit': 'week'}
# {'endDate': '2022-08-28',
#  'results': [{'data': [{'period': '2022-07-18', 'ratio': 100},
#                        {'period': '2022-07-25', 'ratio': 84.8268},
#                        {'period': '2022-08-01', 'ratio': 81.50414},
#                        {'period': '2022-08-08', 'ratio': 83.76317},
#                        {'period': '2022-08-15', 'ratio': 87.56588},
#                        {'period': '2022-08-22', 'ratio': 85.80572}],
#               'keywords': ['비건'],
#               'title': '비건'}],
#  'startDate': '2022-07-18',
#  'timeUnit': 'week'}
# {'endDate': '2022-08-28',
#  'results': [{'data': [{'period': '2022-07-18', 'ratio': 76.03653},
#                        {'period': '2022-07-25', 'ratio': 80.71485},
#                        {'period': '2022-08-01', 'ratio': 90.37331},
#                        {'period': '2022-08-08', 'ratio': 80.8737},
#                        {'period': '2022-08-15', 'ratio': 89.65845},
#                        {'period': '2022-08-22', 'ratio': 100}],
#               'keywords': ['한식'],
#               'title': '한식'}],
#  'startDate': '2022-07-18',
#  'timeUnit': 'week'}
# {'endDate': '2022-08-28',
#  'results': [{'data': [{'period': '2022-07-18', 'ratio': 60.39886},
#                        {'period': '2022-07-25', 'ratio': 54.13105},
#                        {'period': '2022-08-01', 'ratio': 86.32478},
#                        {'period': '2022-08-08', 'ratio': 94.87179},
#                        {'period': '2022-08-15', 'ratio': 100},
#                        {'period': '2022-08-22', 'ratio': 90.02849}],
#               'keywords': ['채식요리'],
#               'title': '채식요리'}],
#  'startDate': '2022-07-18',
#  'timeUnit': 'week'}
# {'endDate': '2022-08-28',
#  'results': [{'data': [{'period': '2022-07-18', 'ratio': 70.86441},
#                        {'period': '2022-07-25', 'ratio': 78.43352},
#                        {'period': '2022-08-01', 'ratio': 83.77577},
#                        {'period': '2022-08-08', 'ratio': 81.29662},
#                        {'period': '2022-08-15', 'ratio': 81.05528},
#                        {'period': '2022-08-22', 'ratio': 100}],
#               'keywords': ['제철음식'],
#               'title': '제철음식'}],
#  'startDate': '2022-07-18',
#  'timeUnit': 'week'}
# {'endDate': '2022-08-28',
#  'results': [{'data': [{'period': '2022-07-18', 'ratio': 100},
#                        {'period': '2022-07-25', 'ratio': 92.03601},
#                        {'period': '2022-08-01', 'ratio': 84.07202},
#                        {'period': '2022-08-08', 'ratio': 85.73407},
#                        {'period': '2022-08-15', 'ratio': 96.8144},
#                        {'period': '2022-08-22', 'ratio': 78.87811}],
#               'keywords': ['비건식당'],
#               'title': '비건식당'}],
#  'startDate': '2022-07-18',
#  'timeUnit': 'week'}
# {'endDate': '2022-08-28',
#  'results': [{'data': [{'period': '2022-07-18', 'ratio': 78.34728},
#                        {'period': '2022-07-25', 'ratio': 67.99163},
#                        {'period': '2022-08-01', 'ratio': 73.84937},
#                        {'period': '2022-08-08', 'ratio': 75.62761},
#                        {'period': '2022-08-15', 'ratio': 80.54393},
#                        {'period': '2022-08-22', 'ratio': 100}],
#               'keywords': ['천연화장품'],
#               'title': '천연화장품'}],
#  'startDate': '2022-07-18',
#  'timeUnit': 'week'}
# {'endDate': '2022-08-28',
#  'results': [{'data': [{'period': '2022-07-18', 'ratio': 46.76486},
#                        {'period': '2022-07-25', 'ratio': 46.58074},
#                        {'period': '2022-08-01', 'ratio': 100},
#                        {'period': '2022-08-08', 'ratio': 89.95265},
#                        {'period': '2022-08-15', 'ratio': 61.36244},
#                        {'period': '2022-08-22', 'ratio': 51.4203}],
#               'keywords': ['단식'],
#               'title': '단식'}],
#  'startDate': '2022-07-18',
#  'timeUnit': 'week'}
# {'endDate': '2022-08-28',
#  'results': [{'data': [{'period': '2022-07-18', 'ratio': 100},
#                        {'period': '2022-07-25', 'ratio': 97.40932},
#                        {'period': '2022-08-01', 'ratio': 85.924},
#                        {'period': '2022-08-08', 'ratio': 89.89637},
#                        {'period': '2022-08-15', 'ratio': 88.68739},
# ...
#  'results': [{'data': [{'period': '2022-07-18', 'ratio': 100},
#                        {'period': '2022-07-25', 'ratio': 64.42307},
#                        {'period': '2022-08-01', 'ratio': 86.53846},
#                        {'period': '2022-08-08', 'ratio': 89.42307},
#                        {'period': '2022-08-15', 'ratio': 99.03846},
#                        {'period': '2022-08-22', 'ratio': 80.76923}],
#               'keywords': ['제로웨이스트수세미'],
#               'title': '제로웨이스트수세미'}],
#  'startDate': '2022-07-18',
#  'timeUnit': 'week'}
# {'endDate': '2022-08-28',
#  'results': [{'data': [{'period': '2022-07-18', 'ratio': 87.09175},
#                        {'period': '2022-07-25', 'ratio': 68.58475},
#                        {'period': '2022-08-01', 'ratio': 74.80559},
#                        {'period': '2022-08-08', 'ratio': 100},
#                        {'period': '2022-08-15', 'ratio': 79.93779},
#                        {'period': '2022-08-22', 'ratio': 94.71228}],
#               'keywords': ['제로웨이스트키트'],
#               'title': '제로웨이스트키트'}],
#  'startDate': '2022-07-18',
#  'timeUnit': 'week'}
# {'endDate': '2022-08-28',
#  'results': [{'data': [{'period': '2022-07-18', 'ratio': 63.14673},
#                        {'period': '2022-07-25', 'ratio': 79.5786},
#                        {'period': '2022-08-01', 'ratio': 86.73482},
#                        {'period': '2022-08-08', 'ratio': 94.92581},
#                        {'period': '2022-08-15', 'ratio': 96.58396},
#                        {'period': '2022-08-22', 'ratio': 100}],
#               'keywords': ['행주'],
#               'title': '행주'}],
#  'startDate': '2022-07-18',
#  'timeUnit': 'week'}
# {'endDate': '2022-08-28',
#  'results': [{'data': [{'period': '2022-07-18', 'ratio': 93.77662},
#                        {'period': '2022-07-25', 'ratio': 91.65398},
#                        {'period': '2022-08-01', 'ratio': 92.98539},
#                        {'period': '2022-08-08', 'ratio': 96.27967},
#                        {'period': '2022-08-15', 'ratio': 98.40231},
#                        {'period': '2022-08-22', 'ratio': 100}],
#               'keywords': ['설거지'],
#               'title': '설거지'}],
#  'startDate': '2022-07-18',
#  'timeUnit': 'week'}
# {'endDate': '2022-08-28',
#  'results': [{'data': [{'period': '2022-07-18', 'ratio': 100},
#                        {'period': '2022-07-25', 'ratio': 14.60423},
#                        {'period': '2022-08-01', 'ratio': 13.60089},
#                        {'period': '2022-08-08', 'ratio': 14.93868},
#                        {'period': '2022-08-15', 'ratio': 27.92642},
#                        {'period': '2022-08-22', 'ratio': 35.61872}],
#               'keywords': ['제주도수학여행'],
#               'title': '제주도수학여행'}],
#  'startDate': '2022-07-18',
#  'timeUnit': 'week'}
# {'endDate': '2022-08-28',
#  'results': [{'data': [{'period': '2022-07-18', 'ratio': 55.55555},
#                        {'period': '2022-07-25', 'ratio': 66.66666},
#                        {'period': '2022-08-01', 'ratio': 46.29629},
#                        {'period': '2022-08-08', 'ratio': 27.77777},
#                        {'period': '2022-08-15', 'ratio': 68.51851},
#                        {'period': '2022-08-22', 'ratio': 100}],
#               'keywords': ['제로웨이스트비누'],
#               'title': '제로웨이스트비누'}],
#  'startDate': '2022-07-18',
#  'timeUnit': 'week'}
# {'endDate': '2022-08-28',
#  'results': [{'data': [{'period': '2022-07-18', 'ratio': 97.9452},
#                        {'period': '2022-07-25', 'ratio': 84.01826},
#                        {'period': '2022-08-01', 'ratio': 76.48401},
#                        {'period': '2022-08-08', 'ratio': 75.34246},
#                        {'period': '2022-08-15', 'ratio': 81.65905},
#                        {'period': '2022-08-22', 'ratio': 100}],
#               'keywords': ['리사이클링'],
#               'title': '리사이클링'}],
#  'startDate': '2022-07-18',
#  'timeUnit': 'week'}
# {'endDate': '2022-08-28',
#  'results': [{'data': [{'period': '2022-07-18', 'ratio': 100},
#                        {'period': '2022-07-25', 'ratio': 83.83045},
#                        {'period': '2022-08-01', 'ratio': 77.3084},
#                        {'period': '2022-08-08', 'ratio': 78.63565},
#                        {'period': '2022-08-15', 'ratio': 79.2065},
#                        {'period': '2022-08-22', 'ratio': 86.15194}],
#               'keywords': ['ESG'],
#               'title': 'ESG'}],
#  'startDate': '2022-07-18',
#  'timeUnit': 'week'}
# {'endDate': '2022-08-28',
#  'results': [{'data': [{'period': '2022-07-18', 'ratio': 77.68643},
#                        {'period': '2022-07-25', 'ratio': 59.42454},
#                        {'period': '2022-08-01', 'ratio': 61.0687},
#                        {'period': '2022-08-08', 'ratio': 68.99588},
#                        {'period': '2022-08-15', 'ratio': 81.56194},
#                        {'period': '2022-08-22', 'ratio': 100}],
#               'keywords': ['업사이클링'],
#               'title': '업사이클링'}],
#  'startDate': '2022-07-18',
#  'timeUnit': 'week'}
# {'endDate': '2022-08-28',
#  'results': [{'data': [{'period': '2022-07-18', 'ratio': 82.79569},
#                        {'period': '2022-07-25', 'ratio': 87.6344},
#                        {'period': '2022-08-01', 'ratio': 67.74193},
#                        {'period': '2022-08-08', 'ratio': 100},
#                        {'period': '2022-08-15', 'ratio': 73.65591},
#                        {'period': '2022-08-22', 'ratio': 81.72043}],
#               'keywords': ['캘러웨이로스트볼'],
#               'title': '캘러웨이로스트볼'}],
#  'startDate': '2022-07-18',
#  'timeUnit': 'week'}
# {'endDate': '2022-08-28',
#  'results': [{'data': [{'period': '2022-07-18', 'ratio': 40.48852},
#                        {'period': '2022-07-25', 'ratio': 100},
#                        {'period': '2022-08-01', 'ratio': 60.99185},
#                        {'period': '2022-08-08', 'ratio': 59.84455},
#                        {'period': '2022-08-15', 'ratio': 60.06661},
#                        {'period': '2022-08-22', 'ratio': 69.57809}],
#               'keywords': ['르무통'],
#               'title': '르무통'}],
#  'startDate': '2022-07-18',
#  'timeUnit': 'week'}
# {'endDate': '2022-08-28',
#  'results': [{'data': [{'period': '2022-08-01', 'ratio': 100}],
#               'keywords': ['제로웨이스트마켓'],
#               'title': '제로웨이스트마켓'}],
#  'startDate': '2022-07-18',
#  'timeUnit': 'week'}
# {'endDate': '2022-08-28',
#  'results': [{'data': [{'period': '2022-07-18', 'ratio': 100},
#                        {'period': '2022-07-25', 'ratio': 79.14438},
#                        {'period': '2022-08-01', 'ratio': 94.11764},
#                        {'period': '2022-08-08', 'ratio': 98.39572},
#                        {'period': '2022-08-15', 'ratio': 66.31016},
#                        {'period': '2022-08-22', 'ratio': 94.6524}],
#               'keywords': ['제로웨이스트실천'],
#               'title': '제로웨이스트실천'}],
#  'startDate': '2022-07-18',
#  'timeUnit': 'week'}
# {'endDate': '2022-08-28',
#  'results': [{'data': [{'period': '2022-07-18', 'ratio': 100},
#                        {'period': '2022-07-25', 'ratio': 83.48909},
#                        {'period': '2022-08-01', 'ratio': 84.31983},
#                        {'period': '2022-08-08', 'ratio': 81.7757},
#                        {'period': '2022-08-15', 'ratio': 65.31671},
#                        {'period': '2022-08-22', 'ratio': 68.4839}],
#               'keywords': ['업사이클링가방'],
#               'title': '업사이클링가방'}],
#  'startDate': '2022-07-18',
#  'timeUnit': 'week'}
# {'endDate': '2022-08-28',
#  'results': [{'data': [{'period': '2022-07-18', 'ratio': 100},
#                        {'period': '2022-07-25', 'ratio': 89.65517},
#                        {'period': '2022-08-01', 'ratio': 79.31034},
#                        {'period': '2022-08-08', 'ratio': 81.77339},
#                        {'period': '2022-08-15', 'ratio': 72.16748},
#                        {'period': '2022-08-22', 'ratio': 89.90147}],
#               'keywords': ['업사이클링브랜드'],
#               'title': '업사이클링브랜드'}],
#  'startDate': '2022-07-18',
#  'timeUnit': 'week'}
# {'endDate': '2022-08-28',
#  'results': [{'data': [{'period': '2022-07-18', 'ratio': 89.59156},
#                        {'period': '2022-07-25', 'ratio': 78.12911},
#                        {'period': '2022-08-01', 'ratio': 77.6021},
#                        {'period': '2022-08-08', 'ratio': 75.49407},
#                        {'period': '2022-08-15', 'ratio': 100},
#                        {'period': '2022-08-22', 'ratio': 82.60869}],
#               'keywords': ['페트병재활용'],
#               'title': '페트병재활용'}],
#  'startDate': '2022-07-18',
#  'timeUnit': 'week'}
# {'endDate': '2022-08-28',
#  'results': [{'data': [{'period': '2022-08-08', 'ratio': 100},
#                        {'period': '2022-08-15', 'ratio': 3.42657},
#                        {'period': '2022-08-22', 'ratio': 0.41958}],
#               'keywords': ['제로웨이스트숙소'],
#               'title': '제로웨이스트숙소'}],
#  'startDate': '2022-07-18',
#  'timeUnit': 'week'}
# {'endDate': '2022-08-28',
#  'results': [{'data': [{'period': '2022-07-18', 'ratio': 100},
#                        {'period': '2022-07-25', 'ratio': 73.15511},
#                        {'period': '2022-08-01', 'ratio': 67.19662},
#                        {'period': '2022-08-08', 'ratio': 70.01758},
#                        {'period': '2022-08-15', 'ratio': 76.29264},
#                        {'period': '2022-08-22', 'ratio': 82.15969}],
#               'keywords': ['esg경영'],
#               'title': 'esg경영'}],
#  'startDate': '2022-07-18',
#  'timeUnit': 'week'}
# {'endDate': '2022-08-28',
#  'results': [{'data': [{'period': '2022-07-18', 'ratio': 100},
#                        {'period': '2022-07-25', 'ratio': 71.68576},
#                        {'period': '2022-08-01', 'ratio': 79.05073},
#                        {'period': '2022-08-08', 'ratio': 86.41571},
#                        {'period': '2022-08-15', 'ratio': 76.10474},
#                        {'period': '2022-08-22', 'ratio': 93.94435}],
#               'keywords': ['제로웨이스트뜻'],
#               'title': '제로웨이스트뜻'}],
#  'startDate': '2022-07-18',
#  'timeUnit': 'week'}
# {'endDate': '2022-08-28',
#  'results': [{'data': [{'period': '2022-07-18', 'ratio': 87.75908},
#                        {'period': '2022-07-25', 'ratio': 78.82262},
#                        {'period': '2022-08-01', 'ratio': 77.31056},
#                        {'period': '2022-08-08', 'ratio': 88.95684},
#                        {'period': '2022-08-15', 'ratio': 95.41284},
#                        {'period': '2022-08-22', 'ratio': 100}],
#               'keywords': ['수세미'],
#               'title': '수세미'}],
#  'startDate': '2022-07-18',
#  'timeUnit': 'week'}
# {'endDate': '2022-08-28',
#  'results': [{'data': [{'period': '2022-07-18', 'ratio': 77.23577},
#                        {'period': '2022-07-25', 'ratio': 56.09756},
#                        {'period': '2022-08-01', 'ratio': 45.52845},
#                        {'period': '2022-08-08', 'ratio': 60.9756},
#                        {'period': '2022-08-15', 'ratio': 64.22764},
#                        {'period': '2022-08-22', 'ratio': 100}],
#               'keywords': ['친환경신발'],
#               'title': '친환경신발'}],
#  'startDate': '2022-07-18',
#  'timeUnit': 'week'}
# {'endDate': '2022-08-28',
#  'results': [{'data': [{'period': '2022-07-18', 'ratio': 70.16528},
#                        {'period': '2022-07-25', 'ratio': 49.83471},
#                        {'period': '2022-08-01', 'ratio': 52.85123},
#                        {'period': '2022-08-08', 'ratio': 60.86776},
#                        {'period': '2022-08-15', 'ratio': 59.00826},
#                        {'period': '2022-08-22', 'ratio': 100}],
#               'keywords': ['친환경제품'],
#               'title': '친환경제품'}],
#  'startDate': '2022-07-18',
#  'timeUnit': 'week'}
# {'endDate': '2022-08-28',
#  'results': [{'data': [{'period': '2022-07-18', 'ratio': 100},
#                        {'period': '2022-07-25', 'ratio': 75.2561},
#                        {'period': '2022-08-01', 'ratio': 72.63987},
#                        {'period': '2022-08-08', 'ratio': 71.21355},
#                        {'period': '2022-08-15', 'ratio': 83.50669},
#                        {'period': '2022-08-22', 'ratio': 86.19385}],
#               'keywords': ['탄소중립'],
#               'title': '탄소중립'}],
#  'startDate': '2022-07-18',
#  'timeUnit': 'week'}
# {'endDate': '2022-08-28',
#  'results': [{'data': [{'period': '2022-07-18', 'ratio': 63.7037},
#                        {'period': '2022-07-25', 'ratio': 59.25925},
#                        {'period': '2022-08-01', 'ratio': 48.88888},
#                        {'period': '2022-08-08', 'ratio': 78.51851},
#                        {'period': '2022-08-15', 'ratio': 74.81481},
#                        {'period': '2022-08-22', 'ratio': 100}],
#               'keywords': ['친환경의류'],
#               'title': '친환경의류'}],
#  'startDate': '2022-07-18',
#  'timeUnit': 'week'}
# {'endDate': '2022-08-28',
#  'results': [{'data': [{'period': '2022-07-18', 'ratio': 70.7317},
#                        {'period': '2022-07-25', 'ratio': 94.51219},
#                        {'period': '2022-08-01', 'ratio': 70.12195},
#                        {'period': '2022-08-08', 'ratio': 75},
#                        {'period': '2022-08-15', 'ratio': 76.82926},
#                        {'period': '2022-08-22', 'ratio': 100}],
#               'keywords': ['대구제로웨이스트'],
#               'title': '대구제로웨이스트'}],
#  'startDate': '2022-07-18',
#  'timeUnit': 'week'}
# {'endDate': '2022-08-28',
#  'results': [{'data': [{'period': '2022-07-18', 'ratio': 83.05084},
#                        {'period': '2022-07-25', 'ratio': 67.79661},
#                        {'period': '2022-08-01', 'ratio': 64.40677},
#                        {'period': '2022-08-08', 'ratio': 59.32203},
#                        {'period': '2022-08-15', 'ratio': 100},
#                        {'period': '2022-08-22', 'ratio': 83.05084}],
#               'keywords': ['친환경운동화'],
#               'title': '친환경운동화'}],
#  'startDate': '2022-07-18',
#  'timeUnit': 'week'}
# {'endDate': '2022-08-28',
#  'results': [{'data': [{'period': '2022-07-18', 'ratio': 85.446},
#                        {'period': '2022-07-25', 'ratio': 100},
#                        {'period': '2022-08-01', 'ratio': 80.65727},
#                        {'period': '2022-08-08', 'ratio': 72.30046},
#                        {'period': '2022-08-15', 'ratio': 64.13145},
#                        {'period': '2022-08-22', 'ratio': 52.48826}],
#               'keywords': ['제주도어린이체험'],
#               'title': '제주도어린이체험'}],
#  'startDate': '2022-07-18',
#  'timeUnit': 'week'}
# {'endDate': '2022-08-28',
#  'results': [{'data': [{'period': '2022-07-18', 'ratio': 93.9759},
#                        {'period': '2022-07-25', 'ratio': 43.37349},
#                        {'period': '2022-08-01', 'ratio': 49.39759},
#                        {'period': '2022-08-08', 'ratio': 95.18072},
#                        {'period': '2022-08-15', 'ratio': 78.31325},
#                        {'period': '2022-08-22', 'ratio': 100}],
#               'keywords': ['제로웨이스트제품'],
#               'title': '제로웨이스트제품'}],
#  'startDate': '2022-07-18',
#  'timeUnit': 'week'}
# {'endDate': '2022-08-28',
#  'results': [{'data': [{'period': '2022-08-01', 'ratio': 71.42857},
#                        {'period': '2022-08-22', 'ratio': 100}],
#               'keywords': ['지구의날행사'],
#               'title': '지구의날행사'}],
#  'startDate': '2022-07-18',
#  'timeUnit': 'week'}
# {'endDate': '2022-08-28',
#  'results': [{'data': [{'period': '2022-07-18', 'ratio': 100},
#                        {'period': '2022-07-25', 'ratio': 64.9315},
#                        {'period': '2022-08-01', 'ratio': 59.86301},
#                        {'period': '2022-08-08', 'ratio': 48.08219},
#                        {'period': '2022-08-15', 'ratio': 68.63013},
#                        {'period': '2022-08-22', 'ratio': 73.69863}],
#               'keywords': ['업사이클링제품'],
#               'title': '업사이클링제품'}],
#  'startDate': '2022-07-18',
#  'timeUnit': 'week'}
#       title      period
# 0       설거지  2022-08-22
# 1     업사이클링  2022-08-22
# 2       후드티  2022-08-22
# 3     친환경신발  2022-08-22
# 4    친환경브랜드  2022-08-22
# 5    지구의날행사  2022-08-22
# 6  제로웨이스트제품  2022-08-22
# 7     친환경제품  2022-08-22
# 8        행주  2022-08-22
# 9       수세미  2022-08-22
# zerowaste commit
